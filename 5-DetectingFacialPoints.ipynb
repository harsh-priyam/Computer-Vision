# %%
import dlib
import cv2
from google.colab.patches import cv2_imshow

# %%
face_detector = dlib.get_frontal_face_detector()
points_detector = dlib.shape_predictor('/content/drive/MyDrive/Weights/shape_predictor_68_face_landmarks.dat')

# %%
image = cv2.imread('/content/drive/MyDrive/Images/people2.jpg')
face_detection = face_detector(image,1)
for face in face_detection:
   points = points_detector(image, face)
   for point in points.parts():
         cv2.circle(image,(point.x,point.y),2,(0,255,0),1)
   l,t,r,b = face.left(), face.top(), face.right(), face.bottom()
   cv2.rectangle(image, (l,t), (r,b), (0,255,0), 2)
cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=RGB size=1023x537 at 0x7FCEADC089D0>
